# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
input_dim = x_train.shape[1] # 784 (28*28)
encoding_dim = 32 # You can adjust this value
input_img = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(input_dim, activation='sigmoid')(encoded)
autoencoder = Model(input_img, decoded)
encoder = Model(input_img, encoded)
autoencoder.compile(optimizer=Adam(), loss='binary_crossentropy')

# %%
history = autoencoder.fit(x_train, x_train,
epochs=50,
batch_size=256,
shuffle=True,
validation_data=(x_test, x_test))


encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0925 - val_loss: 0.0911
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - val_loss: 0.0911
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.0911
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.0911
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.0911
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0923 - val_loss: 0.0913
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.0911
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.0911
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0911
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0921 - val_loss: 0.0911
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.0910
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0910
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - val_loss: 0.0911
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0910
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0918 - val_loss: 0.0910
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0923 - val_loss: 0.0910
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.0910
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0910
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0912
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0919 - val_loss: 0.0910
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0919 - val_loss: 0.0910
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0923 - val_loss: 0.0910
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0910
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - val_loss: 0.0909
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0918 - val_loss: 0.0910
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0921 - val_loss: 0.0909
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0918 - val_loss: 0.0909
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0921 - val_loss: 0.0909
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.0909
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0919 - val_loss: 0.0909
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0919 - val_loss: 0.0909
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0910
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0919 - val_loss: 0.0910
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0917 - val_loss: 0.0911
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920 - val_loss: 0.0908
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0917 - val_loss: 0.0909
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0918 - val_loss: 0.0909
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
n = 10 # Number of images to display
plt.figure(figsize=(18, 8))
for i in range(n):
    # Original images
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.title("Original")
    plt.gray()
    ax.axis('off')
    # Encoded images (dimensionality reduced representation)
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(encoded_imgs[i].reshape(4, 8)) # Reshape for visualization
    plt.title("Encoded")
    plt.gray()
    ax.axis('off')
    # Reconstructed images
    ax = plt.subplot(3, n, i + 1 + 2*n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.title("Reconstructed")
    plt.gray()
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
plt.gray()
ax.axis('off')

ax = plt.subplot(3, n, i + 1 + 2 * n)
plt.imshow(decoded_imgs[i].reshape(28, 28))
plt.title("Reconstructed")
plt.gray()
ax.axis('off')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss during Training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
